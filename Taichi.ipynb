# %%
# Tested on Python 3.8.18 
import sys
# !{sys.executable} -m pip install taichi==1.7.0  # Install Taichi Lang
# Out:
# Requirement already satisfied: taichi==0.7.13 in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (0.7.13)
# Requirement already satisfied: numpy in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi==0.7.13) (1.24.4)
# Requirement already satisfied: pybind11>=2.5.0 in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi==0.7.13) (2.11.1)
# Requirement already satisfied: sourceinspect>=0.0.4 in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi==0.7.13) (0.0.4)
# Requirement already satisfied: colorama in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi==0.7.13) (0.4.6)
# Requirement already satisfied: astor in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi==0.7.13) (0.8.1)
# Requirement already satisfied: dill in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from sourceinspect>=0.0.4->taichi==0.7.13) (0.3.7)
# Requirement already satisfied: taichi-tina in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (0.1.1)
# Requirement already satisfied: taichi in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi-tina) (0.7.13)
# Requirement already satisfied: numpy in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi->taichi-tina) (1.24.4)
# Requirement already satisfied: pybind11>=2.5.0 in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi->taichi-tina) (2.11.1)
# Requirement already satisfied: sourceinspect>=0.0.4 in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi->taichi-tina) (0.0.4)
# Requirement already satisfied: colorama in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi->taichi-tina) (0.4.6)
# Requirement already satisfied: astor in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from taichi->taichi-tina) (0.8.1)
# Requirement already satisfied: dill in /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages (from sourceinspect>=0.0.4->taichi->taichi-tina) (0.3.7)

# %%
import taichi as ti
import math

# %%
real = ti.f32
ti.init(default_fp=real, debug=True)

max_steps = 1024
vis_interval = 256
output_vis_interval = 8
steps = 1024

vis_resolution = 1024

n_objects = 3
mass = 1
n_springs = 3
spring_stiffness = 10
damping = 20

scalar = lambda: ti.field(dtype=real)
vec = lambda: ti.Vector.field(2, dtype=real)

loss = scalar()
x = vec()
v = vec()
force = vec()

spring_anchor_a = ti.field(ti.i32)
spring_anchor_b = ti.field(ti.i32)
spring_length = scalar()

dt = 0.001
learning_rate = 5

friction = 0.01
# Out:
# [Taichi] Starting on arch=x64

# %%
def allocate_fields():
    ti.root.dense(ti.i, max_steps).dense(ti.j, n_objects).place(x, v, force)
    ti.root.dense(ti.i, n_springs).place(spring_anchor_a, spring_anchor_b,
                                         spring_length)
    ti.root.place(loss)
    ti.root.lazy_grad()

@ti.kernel
def apply_spring_force(t: ti.i32):
    # Kernels can have parameters. there t is a parameter with type int32.
    for i in range(n_springs):  # A parallel for, preferably on GPUs
        a, b = spring_anchor_a[i], spring_anchor_b[i]
        x_a, x_b = x[t - 1, a], x[t - 1, b]
        dist = x_a - x_b
        length = dist.norm() + 1e-4
        F = (length - spring_length[i]) * spring_stiffness * dist / length
        # apply spring impulses to mass points. Use atomic_add for parallel safety.
        ti.atomic_add(force[t, a], -F)
        ti.atomic_add(force[t, b], F)




@ti.kernel
def time_integrate(t: ti.i32):
    for i in range(n_objects):
        s = math.exp(-dt * damping)
        new_v = s * v[t - 1, i] + dt * force[t, i] / mass
        new_x = x[t - 1, i] + dt * new_v
        if new_x[0] > 0.4 and new_v[0] > 0:
            # friction projection
            if new_v[1] > 0:
                new_v[1] -= ti.min(new_v[1], friction * new_v[0])
            if new_v[1] < 0:
                new_v[1] += ti.min(-new_v[1], friction * new_v[0])
            new_v[0] = 0
        v[t, i] = new_v
        x[t, i] = new_x


@ti.kernel
def compute_loss(t: ti.i32):
    x01 = x[t, 0] - x[t, 1]
    x02 = x[t, 0] - x[t, 2]
    area = ti.abs(
        0.5 * (x01[0] * x02[1] - x01[1] * x02[0]))  # area from cross product
    target_area = 0.1
    loss[None] = (area - target_area)**2


def forward():
    for t in range(1, steps):
        apply_spring_force(t)
        time_integrate(t)

    compute_loss(steps - 1)


@ti.kernel
def clear_states():
    for t in range(0, max_steps):
        for i in range(0, n_objects):
            x.grad[t, i] = ti.Vector([0.0, 0.0])
            v.grad[t, i] = ti.Vector([0.0, 0.0])
            force[t, i] = ti.Vector([0.0, 0.0])
            force.grad[t, i] = ti.Vector([0.0, 0.0])


@ti.kernel
def clear_springs():
    for i in range(n_springs):
        spring_length.grad[i] = 0.0


def clear_tensors():
    clear_states()
    clear_springs()

# %%
allocate_fields()
x[0, 0] = [0.3, 0.5]
x[0, 1] = [0.3, 0.4]
x[0, 2] = [0.4, 0.4]

spring_anchor_a[0], spring_anchor_b[0], spring_length[0] = 0, 1, 0.1
spring_anchor_a[1], spring_anchor_b[1], spring_length[1] = 1, 2, 0.1
spring_anchor_a[2], spring_anchor_b[2], spring_length[
    2] = 2, 0, 0.1 * 2**0.5

clear_tensors()
forward()

losses = []
for iter in range(25):
    clear_tensors()

    with ti.ad.Tape(loss):
        forward()

    print('Iter=', iter, 'Loss=', loss[None])
    losses.append(loss[None])

    for i in range(n_springs):
        spring_length[i] -= learning_rate * spring_length.grad[i]

for i in range(n_springs):
    print(i, spring_length[i])

clear_tensors()
forward()
# Out:
# [E 11/30/23 12:46:03.429] [snode.cpp:place@44] This variable has been placed.
#
#
# ***********************************
# * Taichi Compiler Stack Traceback *
# ***********************************
# /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages/taichi/core/../lib/taichi_core.so: taichi::Logger::error(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, bool)
# /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages/taichi/core/../lib/taichi_core.so: taichi::lang::SNode::place(taichi::lang::Expr&, std::vector<int, std::allocator<int> > const&)
# /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages/taichi/core/../lib/taichi_core.so(+0x57ecf5) [0x7fb52ce9ccf5]
# /home/taco/miniconda3/envs/taichi/lib/python3.8/site-packages/taichi/core/../lib/taichi_core.so(+0x3f4d44) [0x7fb52cd12d44]
# /home/taco/miniconda3/envs/taichi/bin/python: PyCFunction_Call
# /home/taco/miniconda3/envs/taichi/bin/python: _PyObject_MakeTpCall
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4f531d]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4f50db]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4f50db]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: PyEval_EvalCodeEx
# /home/taco/miniconda3/envs/taichi/bin/python: PyEval_EvalCode
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x589f31]
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4e8cfb]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4f3925]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4f5154]
# /home/taco/miniconda3/envs/taichi/bin/python: PyObject_Call
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4f50db]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4fc29b]
# /home/taco/miniconda3/envs/taichi/lib/python3.8/lib-dynload/_asyncio.cpython-38-x86_64-linux-gnu.so(+0x7023) [0x7fb555350023]
# /home/taco/miniconda3/envs/taichi/lib/python3.8/lib-dynload/_asyncio.cpython-38-x86_64-linux-gnu.so(+0x7813) [0x7fb555350813]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyObject_MakeTpCall
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4a0fe4]
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4dfad2]
# /home/taco/miniconda3/envs/taichi/bin/python: PyVectorcall_Call
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4f50db]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: PyEval_EvalCodeEx
# /home/taco/miniconda3/envs/taichi/bin/python: PyEval_EvalCode
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x589f31]
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x4e8cfb]
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalFrameDefault
# /home/taco/miniconda3/envs/taichi/bin/python: _PyEval_EvalCodeWithName
# /home/taco/miniconda3/envs/taichi/bin/python: _PyFunction_Vectorcall
# /home/taco/miniconda3/envs/taichi/bin/python: PyObject_Call
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x5a2471]
# /home/taco/miniconda3/envs/taichi/bin/python: Py_RunMain
# /home/taco/miniconda3/envs/taichi/bin/python: Py_BytesMain
# /lib/x86_64-linux-gnu/libc.so.6: __libc_start_main
# /home/taco/miniconda3/envs/taichi/bin/python: ) [0x579d3d]
#
# Internal error occurred. Check out this page for possible solutions:
# https://taichi.readthedocs.io/en/stable/install.html#troubleshooting
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/taco/diff_sim_control/Examples/Taichi.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> allocate_fields()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> x[0, 0] = [0.3, 0.5]
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> x[0, 1] = [0.3, 0.4]
#
# /home/taco/diff_sim_control/Examples/Taichi.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def allocate_fields():
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     ti.root.dense(ti.i, max_steps).dense(ti.j, n_objects).place(x, v, force)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     ti.root.dense(ti.i, n_springs).place(spring_anchor_a, spring_anchor_b,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>                                          spring_length)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/taco/diff_sim_control/Examples/Taichi.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     ti.root.place(loss)
#
# File ~/miniconda3/envs/taichi/lib/python3.8/site-packages/taichi/lang/snode.py:68, in place(self, offset, shared_exponent, *args)
#      65 def dynamic(self, axis, dimension, chunk_size=None):
#      66     """Adds a dynamic SNode as a child component of `self`.
#      67
# ---> 68     Args:
#      69         axis (List[Axis]): Axis to activate, must be 1.
#      70         dimension (int): Shape of the axis.
#      71         chunk_size (int): Chunk size.
#      72
#      73     Returns:
#      74         The added :class:`~taichi.lang.SNode` instance.
#      75     """
#      76     if not _ti_core.is_extension_supported(impl.current_cfg().arch, _ti_core.Extension.sparse):
#      77         raise TaichiRuntimeError("Dynamic SNode is not supported on this backend.")
#
# File ~/miniconda3/envs/taichi/lib/python3.8/site-packages/taichi/lang/snode.py:66, in place(self, offset, shared_exponent, *args)
#      65 def dynamic(self, axis, dimension, chunk_size=None):
# ---> 66     """Adds a dynamic SNode as a child component of `self`.
#      67
#      68     Args:
#      69         axis (List[Axis]): Axis to activate, must be 1.
#      70         dimension (int): Shape of the axis.
#      71         chunk_size (int): Chunk size.
#      72
#      73     Returns:
#      74         The added :class:`~taichi.lang.SNode` instance.
#      75     """
#      76     if not _ti_core.is_extension_supported(impl.current_cfg().arch, _ti_core.Extension.sparse):
#      77         raise TaichiRuntimeError("Dynamic SNode is not supported on this backend.")
#
# File ~/miniconda3/envs/taichi/lib/python3.8/site-packages/taichi/lang/snode.py:63, in place(self, offset, shared_exponent, *args)
#      59     """Not supported."""
#      60     raise RuntimeError("hash not yet supported")
#      61     # if isinstance(dimensions, int):
#      62     #     dimensions = [dimensions] * len(axes)
# ---> 63     # return SNode(self.ptr.hash(axes, dimensions))
#      65 def dynamic(self, axis, dimension, chunk_size=None):
#      66     """Adds a dynamic SNode as a child component of `self`.
#      67
#      68     Args:
#    (...)
#      74         The added :class:`~taichi.lang.SNode` instance.
#      75     """
#
# RuntimeError: [snode.cpp:place@44] This variable has been placed.
